# %%
#pip install sqlalchemy

# %%
#pip install pymysql

# %%
import pandas as pd
import numpy as np
import scipy as sp
#import sqlalchemy as db
#import pymysql

# %%
#Must use SQLAlchemy to get data!
df = pd.read_excel(r'C:\Users\ROG\Desktop\MLBootcamp\Project1\Finals\0000\final.xlsx')
df
# Out:
#                 Name                  timeOpen                   timeClose  \
# 0        0x Protocol  2023-08-31T00:00:00.000Z  "2023-08-31T23:59:59.999Z"
# 1        0x Protocol  2023-08-30T00:00:00.000Z  "2023-08-30T23:59:59.999Z"
# 2        0x Protocol  2023-08-29T00:00:00.000Z  "2023-08-29T23:59:59.999Z"
# 3        0x Protocol  2023-08-28T00:00:00.000Z  "2023-08-28T23:59:59.999Z"
# 4        0x Protocol  2023-08-27T00:00:00.000Z  "2023-08-27T23:59:59.999Z"
# ...              ...                       ...                         ...
# 70325  yearn.finance  2022-09-06T00:00:00.000Z  "2022-09-06T23:59:59.999Z"
# 70326  yearn.finance  2022-09-05T00:00:00.000Z  "2022-09-05T23:59:59.999Z"
# 70327  yearn.finance  2022-09-04T00:00:00.000Z  "2022-09-04T23:59:59.999Z"
# 70328  yearn.finance  2022-09-03T00:00:00.000Z  "2022-09-03T23:59:59.999Z"
# 70329  yearn.finance  2022-09-02T00:00:00.000Z  "2022-09-02T23:59:59.999Z"
#
# ...

# %%
##subtraction column needed showing raise or fall respective to the day before

# %% [markdown]
# Statistics question one

# %%
def salary_stats(value):
    if value < 100000000000:
        return "low"
    if 10000 <= value < 300000000000:
        return "average"
    elif 25000 <= value < 500000000000:
        return "high"

q1 = df[['Name','timestamp','marketCap', 'volume']]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(figsize = (8,8))

plt.scatter(q1['marketCap'], q1['volume'])

plt.title('Daily volume by market cap', fontsize = 14)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)

plt.show()

# %%
q1['mc_stats'] = q1['marketCap'].map(salary_stats)
q1
# Out:
# C:\Users\ROG\AppData\Local\Temp\ipykernel_26648\2553332210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   q1['mc_stats'] = q1['marketCap'].map(salary_stats)
#                 Name                   timestamp     marketCap        volume  \
# 0        0x Protocol  "2023-08-31T23:59:59.999Z"  1.398643e+08  8.818782e+06
# 1        0x Protocol  "2023-08-30T23:59:59.999Z"  1.470167e+08  5.742333e+06
# 2        0x Protocol  "2023-08-29T23:59:59.999Z"  1.517058e+08  8.196430e+06
# 3        0x Protocol  "2023-08-28T23:59:59.999Z"  1.451768e+08  8.435254e+06
# 4        0x Protocol  "2023-08-27T23:59:59.999Z"  1.455405e+08  5.308185e+06
# ...              ...                         ...           ...           ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.lmplot(x = 'marketCap', y = 'volume', data = q1, hue = 'mc_stats', palette=['red','green','orange'], fit_reg = False)

plt.title('Daily volume by market cap Classified!', fontsize = 12)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)

plt.show()

# %% [markdown]
# Statistics question two

# %% [markdown]
# Statistics question three

# %%
##finding mineable tag id from tags table
##finding coins with the related coinid from cointag pivot
##filtering mineables
##filtering finals by mineables
##plotting filtered finals volume

# %% [markdown]
# Statistics question four

# %%
##finding latest marketcap of each coin
##filtering top 16
##corrmatrix

# %% [markdown]
# Statistics question five

# %% [markdown]
# Estimation

# %%
##Plotting pop dist
##sampling in 40
##volume mean in each category
##confidence interval

# %% [markdown]
# Hypo test 1

# %%
##filtering data by days
##price subtraction mean
##data plotting
##hypo testing

# %% [markdown]
# Hypo test 2

# %%
##nothing special!

# %% [markdown]
# Any other useful statistical interference!
