# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آمارتوصیفی
# </font>
# </h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import statistics as st
from itertools import combinations
import seaborn as sns
import mysql.connector

# %%
conn=mysql.connector.connect(host='localhost', user='root', password='arvin1381', database='a',raise_on_warnings= True)

# %%
cu=conn.cursor()

# %%
cu.execute('select * from coinhistories')
tab1=cu.fetchall()
cu.execute('select * from coins')
tab2=cu.fetchall()

# %%
coinhis=pd.DataFrame(tab1,columns=['id', 'name', 'Date', 'open', 'timeHigh', 'high', 'timeLow', 'low','close', 'volume', 'marketCap', 'DailyPrice', 'CirculatingSupply','DailyChange', 'ChangeStatus'])
coin=pd.DataFrame(tab2,columns=['rank', 'name', 'symbol', 'MainLink', 'HistoricalLink', 'Github_link'])

# %%
coinhis['Price change']=coinhis['close']-coinhis['open']

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ۱)ارتباط میان ارزش معاملات و حجم معاملات روزانه
# </font>
# </p>

# %% [markdown]
# Plotting daily volume by market cap per coin

# %%
fig, axes = plt.subplots(figsize = (10,10))

plt.scatter(coinhis['marketCap'], coinhis['volume'])

plt.title('Daily volume by market cap', fontsize = 14)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)
# Out:
# Text(0, 0.5, 'Coin daily volume')

# %% [markdown]
# Categorizing based on the previous plot.

# %%
def salary_stats(value):
    if value < 100000000000:
        return "low"
    if value < 300000000000:
        return "average"
    elif value < 500000000000:
        return "high"

# %%
coinhis['mc_stats'] = coinhis['marketCap'].map(salary_stats)
coinhis
# Out:
#           id       name        Date      open        timeHigh      high  \
# 0          1  Synthetix  2023-08-31  1.995610 0 days 02:57:00  2.024010
# 1          2  Synthetix  2023-08-30  2.060950 0 days 00:55:00  2.084900
# 2          3  Synthetix  2023-08-29  2.080950 0 days 04:46:00  2.137080
# 3          4  Synthetix  2023-08-28  2.107940 0 days 02:36:00  2.139600
# 4          5  Synthetix  2023-08-27  2.071460 0 days 06:44:00  2.148910
# ...      ...        ...         ...       ...             ...       ...
# 70325  70326     Render  2022-09-06  0.500139 0 days 02:28:00  0.507269
# 70326  70327     Render  2022-09-05  0.516513 0 days 00:07:00  0.520092
# 70327  70328     Render  2022-09-04  0.509291 0 days 03:07:00  0.518565
# 70328  70329     Render  2022-09-03  0.520313 0 days 00:50:00  0.521055
# 70329  70330     Render  2022-09-02  0.523143 0 days 05:16:00  0.539434
#
#               timeLow       low     close      volume    marketCap  \
# 0     0 days 02:14:00  1.923430  1.928390  43897700.0  519682000.0
# 1     0 days 03:59:00  1.995570  1.995570  31366400.0  537271000.0
# 2     0 days 00:40:00  2.037480  2.060970  45715400.0  554878000.0
# 3     0 days 01:46:00  2.079480  2.081030  23323500.0  560049000.0
# 4     0 days 00:00:00  2.071460  2.107940  21101900.0  567291000.0
# ...               ...       ...       ...         ...          ...
# 70325 0 days 00:13:00  0.469257  0.469789   9924320.0  119232000.0
# 70326 0 days 00:49:00  0.484872  0.500219  10377500.0  126955000.0
# 70327 0 days 08:08:00  0.497843  0.516505   4796500.0  131088000.0
# 70328 0 days 07:55:00  0.501718  0.509214   4426980.0  129238000.0
# 70329 0 days 09:40:00  0.509584  0.520306   9301720.0  132053000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 0        1.928390        269491000.0    -0.067185          Red     -0.067220
# 1        1.995570        269232000.0    -0.065396          Red     -0.065380
# 2        2.060970        269232000.0    -0.020060          Red     -0.019980
# 3        2.081030        269121000.0    -0.026909          Red     -0.026910
# 4        2.107940        269121000.0     0.036344        Green      0.036480
# ...           ...                ...          ...          ...           ...
# 70325    0.469789        253799000.0    -0.030430          Red     -0.030350
# 70326    0.500219        253799000.0    -0.016286          Red     -0.016294
# 70327    0.516505        253799000.0     0.007291        Green      0.007214
# 70328    0.509214        253799000.0    -0.011092          Red     -0.011099
# 70329    0.520306        253799000.0     0.000000         Gray     -0.002837
#
#       mc_stats
# 0          low
# 1          low
# 2          low
# 3          low
# 4          low
# ...        ...
# 70325      low
# 70326      low
# 70327      low
# 70328      low
# 70329      low
#
# [70330 rows x 17 columns]

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.lmplot(x = 'marketCap', y = 'volume', data = coinhis, hue = 'mc_stats', palette=['red','orange','green'], fit_reg = True)

plt.title('Daily volume by market cap categorized!', fontsize = 12)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)

plt.show()

# %% [markdown]
# Clustering (categorizing) using kmeans

# %%
from scipy.cluster.vq import kmeans, vq
y = np.array(coinhis['marketCap'])
codebook, _ = kmeans(y, 3)
cluster_indices, _ = vq(y, codebook)
coinhis['clusters'] = cluster_indices

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.lmplot(x = 'marketCap', y = 'volume', data = coinhis, hue = 'clusters', palette=['red','orange','green'], fit_reg = True)

plt.title('Daily volume by market cap categorized!', fontsize = 12)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)

plt.show()

# %% [markdown]
# As it shows, it's not always what you see!
#
# Either our clusters are very similar or our chosen thresholds based on eye observations were invalid!

# %% [markdown]
# Trying Two clusters too!

# %%
def salary_stats(value):
    if value < 280000000000:
        return "low"
    else:
        return "high"

# %%
coinhis['mc_stats'] = coinhis['marketCap'].map(salary_stats)
coinhis
# Out:
#           id       name        Date      open        timeHigh      high  \
# 0          1  Synthetix  2023-08-31  1.995610 0 days 02:57:00  2.024010
# 1          2  Synthetix  2023-08-30  2.060950 0 days 00:55:00  2.084900
# 2          3  Synthetix  2023-08-29  2.080950 0 days 04:46:00  2.137080
# 3          4  Synthetix  2023-08-28  2.107940 0 days 02:36:00  2.139600
# 4          5  Synthetix  2023-08-27  2.071460 0 days 06:44:00  2.148910
# ...      ...        ...         ...       ...             ...       ...
# 70325  70326     Render  2022-09-06  0.500139 0 days 02:28:00  0.507269
# 70326  70327     Render  2022-09-05  0.516513 0 days 00:07:00  0.520092
# 70327  70328     Render  2022-09-04  0.509291 0 days 03:07:00  0.518565
# 70328  70329     Render  2022-09-03  0.520313 0 days 00:50:00  0.521055
# 70329  70330     Render  2022-09-02  0.523143 0 days 05:16:00  0.539434
#
#               timeLow       low     close      volume    marketCap  \
# 0     0 days 02:14:00  1.923430  1.928390  43897700.0  519682000.0
# 1     0 days 03:59:00  1.995570  1.995570  31366400.0  537271000.0
# 2     0 days 00:40:00  2.037480  2.060970  45715400.0  554878000.0
# 3     0 days 01:46:00  2.079480  2.081030  23323500.0  560049000.0
# 4     0 days 00:00:00  2.071460  2.107940  21101900.0  567291000.0
# ...               ...       ...       ...         ...          ...
# 70325 0 days 00:13:00  0.469257  0.469789   9924320.0  119232000.0
# 70326 0 days 00:49:00  0.484872  0.500219  10377500.0  126955000.0
# 70327 0 days 08:08:00  0.497843  0.516505   4796500.0  131088000.0
# 70328 0 days 07:55:00  0.501718  0.509214   4426980.0  129238000.0
# 70329 0 days 09:40:00  0.509584  0.520306   9301720.0  132053000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 0        1.928390        269491000.0    -0.067185          Red     -0.067220
# 1        1.995570        269232000.0    -0.065396          Red     -0.065380
# 2        2.060970        269232000.0    -0.020060          Red     -0.019980
# 3        2.081030        269121000.0    -0.026909          Red     -0.026910
# 4        2.107940        269121000.0     0.036344        Green      0.036480
# ...           ...                ...          ...          ...           ...
# 70325    0.469789        253799000.0    -0.030430          Red     -0.030350
# 70326    0.500219        253799000.0    -0.016286          Red     -0.016294
# 70327    0.516505        253799000.0     0.007291        Green      0.007214
# 70328    0.509214        253799000.0    -0.011092          Red     -0.011099
# 70329    0.520306        253799000.0     0.000000         Gray     -0.002837
#
#       mc_stats  clusters
# 0          low         1
# 1          low         1
# 2          low         1
# 3          low         1
# 4          low         1
# ...        ...       ...
# 70325      low         1
# 70326      low         1
# 70327      low         1
# 70328      low         1
# 70329      low         1
#
# [70330 rows x 18 columns]

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.lmplot(x = 'marketCap', y = 'volume', data = coinhis, hue = 'mc_stats', palette=['red','green'], fit_reg = True)

plt.title('Daily volume by market cap categorized!', fontsize = 12)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)

plt.show()

# %%
y = np.array(coinhis['marketCap'])
codebook, _ = kmeans(y, 2)
cluster_indices, _ = vq(y, codebook)
coinhis['clusters'] = cluster_indices

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
sns.lmplot(x = 'marketCap', y = 'volume', data = coinhis, hue = 'clusters', palette=['red','green'], fit_reg = True)

plt.title('Daily volume by market cap categorized!', fontsize = 12)
plt.xlabel('Coin market cap', fontsize = 10)
plt.ylabel('Coin daily volume', fontsize = 10)

plt.show()

# %% [markdown]
# It seems that scipy's clustering method needs a real shake!

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ۲)تغییرات هم سو
# </font>
# </p>

# %% [markdown]
# Finding integrated coins

# %%
names=list(coin['name'])
name_per=list(combinations(names,2))

# %%
s_dir=[]
for iter in name_per:
    first=coinhis[coinhis['name']==iter[0]][['Date','Price change']]
    second=coinhis[coinhis['name']==iter[1]][['Date','Price change']]
    counter=0
    for k in range(min(len(first),len(second))):
        if (first.iloc[k]['Price change'] * second.iloc[k]['Price change'])>=0:
            counter+=1
    s_dir.append((counter,iter[0],iter[1]))

# %%
s_dir.sort(key=lambda x:x[0],reverse=True)

# %%
pd.DataFrame(s_dir[:30],columns=['count',
            'first coin',
            'second coin'],index=list(range(1,31)))
# Out:
#     count             first coin       second coin
# 1     351                Bitcoin   Wrapped Bitcoin
# 2     323           Decentraland       The Sandbox
# 3     318               Ethereum            Gnosis
# 4     317             Enjin Coin       The Sandbox
# 5     314               Ethereum   Wrapped Bitcoin
# 6     310           Decentraland        Enjin Coin
# 7     310           Decentraland     Oasis Network
# 8     310           Decentraland           VeChain
# 9     309          Axie Infinity       The Sandbox
# 10    309                Bitcoin          Ethereum
# 11    309          Oasis Network       The Sandbox
# 12    308            0x Protocol           VeChain
# 13    308                   Ankr           Zilliqa
# 14    308          Axie Infinity      Decentraland
# 15    308                   ICON       The Sandbox
# 16    307          1inch Network     Oasis Network
# 17    307  Basic Attention Token          Ontology
# 18    307                  Tezos           VeChain
# 19    306              Avalanche              Holo
# 20    306          Axie Infinity     Oasis Network
# 21    306                    BNB       PancakeSwap
# 22    306                Cardano  Ethereum Classic
# 23    306                Cardano           Harmony
# 24    306                   ICON              IOST
# 25    306                  Tezos       The Sandbox
# 26    305            0x Protocol              ICON
# 27    305                   Ankr              ICON
# 28    305                   ICON         Threshold
# 29    304              Avalanche  Ethereum Classic
# 30    304              Avalanche             Tezos

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ۳)توزیع حجم ارزهای استخراج پذیر  </font>
# </p>

# %% [markdown]
# Plotting mineables daily volume
#
# Then zooming a little bit!

# %%
cu.execute('select * from cointag')
tab3=cu.fetchall()
cointag=pd.DataFrame(tab3,columns=['Name', 'Tags'])
cointag
# Out:
#          Name                    Tags
# 0     Bitcoin                Mineable
# 1     Bitcoin                     PoW
# 2     Bitcoin                 SHA-256
# 3    Ethereum                     PoS
# 4    Ethereum         Smart Contracts
# ..        ...                     ...
# 558    Status                   Media
# 559    Status        Content Creation
# 560    Status                 Privacy
# 561       Amp      SEC Security Token
# 562       Amp  Alleged SEC Securities
#
# [563 rows x 2 columns]

# %%
mineables = cointag[cointag['Tags'] == 'Mineable']
mineables
# Out:
#                  Name      Tags
# 0             Bitcoin  Mineable
# 21           Dogecoin  Mineable
# 42           Litecoin  Mineable
# 51       Bitcoin Cash  Mineable
# 75             Monero  Mineable
# 84   Ethereum Classic  Mineable
# 93           Filecoin  Mineable
# 148            Stacks  Mineable
# 169        Bitcoin SV  Mineable
# 223             Zcash  Mineable
# 241           Conflux  Mineable
# 284              Dash  Mineable
# 299           Zilliqa  Mineable
# 329            Helium  Mineable
# 341      Bitcoin Gold  Mineable
# 358            Decred  Mineable
# 364         Ravencoin  Mineable
# 421           Siacoin  Mineable
# 483            Kadena  Mineable
# 490    Nervos Network  Mineable
# 493          DigiByte  Mineable
# 512              Flux  Mineable
# 518           Horizen  Mineable

# %%
mineableshis = coinhis[coinhis['name'].isin(mineables['Name'])]
mineableshis
# Out:
#           id        name        Date     open        timeHigh     high  \
# 728      729  Bitcoin SV  2023-08-31  32.6322 0 days 01:46:00  33.1578
# 729      730  Bitcoin SV  2023-08-30  33.7950 0 days 00:01:00  33.8772
# 730      731  Bitcoin SV  2023-08-29  31.2698 0 days 07:37:00  34.5275
# 731      732  Bitcoin SV  2023-08-28  31.0865 0 days 03:23:00  31.7191
# 732      733  Bitcoin SV  2023-08-27  29.9220 0 days 03:14:00  31.6948
# ...      ...         ...         ...      ...             ...      ...
# 64137  64138       Zcash  2022-09-06  63.4368 0 days 01:19:00  66.0212
# 64138  64139       Zcash  2022-09-05  63.8739 0 days 00:07:00  64.1982
# 64139  64140       Zcash  2022-09-04  62.6346 0 days 08:29:00  64.1235
# 64140  64141       Zcash  2022-09-03  60.2619 0 days 03:58:00  62.6377
# 64141  64142       Zcash  2022-09-02  59.0230 0 days 06:18:00  61.6830
#
#               timeLow      low    close      volume    marketCap  DailyPrice  \
# 728   0 days 01:49:00  31.1920  31.2290  25036200.0  601659000.0     31.2290
# 729   0 days 07:09:00  32.3723  32.6291  25312400.0  628635000.0     32.6291
# 730   0 days 09:08:00  30.6462  33.7808  43793500.0  650823000.0     33.7808
# 731   0 days 00:25:00  30.1708  31.2593  32792600.0  602243000.0     31.2593
# 732   0 days 01:45:00  29.8195  31.0900  35531300.0  598983000.0     31.0900
# ...               ...      ...      ...         ...          ...         ...
# 64137 0 days 03:58:00  58.2331  58.2374  73502100.0  885655000.0     58.2374
# 64138 0 days 00:49:00  62.2915  63.4466  52197700.0  964421000.0     63.4466
# 64139 0 days 04:45:00  62.1367  63.8721  58593000.0  970429000.0     63.8721
# 64140 0 days 00:10:00  60.1089  62.6326  62869700.0  951150000.0     62.6326
# 64141 0 days 02:31:00  58.2427  60.2568  66059000.0  914636000.0     60.2568
#
#        CirculatingSupply  DailyChange ChangeStatus  Price change mc_stats  \
# 728           19266100.0    -1.400170          Red       -1.4032      low
# 729           19266100.0    -1.151650          Red       -1.1659      low
# 730           19266100.0     2.521510        Green        2.5110      low
# 731           19266100.0     0.169223        Green        0.1728      low
# 732           19266100.0     1.165850        Green        1.1680      low
# ...                  ...          ...          ...           ...      ...
# 64137         15207700.0    -5.209170          Red       -5.1994      low
# 64138         15200500.0    -0.425481          Red       -0.4273      low
# 64139         15193300.0     1.239500        Green        1.2375      low
# 64140         15186200.0     2.375810        Green        2.3707      low
# 64141         15179000.0     0.000000         Gray        1.2338      low
#
#        clusters
# 728           0
# 729           0
# 730           0
# 731           0
# 732           0
# ...         ...
# 64137         0
# 64138         0
# 64139         0
# 64140         0
# 64141         0
#
# [8372 rows x 18 columns]

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(mineableshis['volume'],bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(mineableshis['volume'],bins = 1000, edgecolor = "black", align = 'mid')
ax.set_xlim(0,13000000000)
ax.set_ylim(0,5000)
ax.set_title('Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(mineableshis['volume'],bins = 2000, edgecolor = "black", align = 'mid')
ax.set_xlim(0,7000000000)
ax.set_ylim(0,2000)
ax.set_title('Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(mineableshis['volume'],bins = 3000, edgecolor = "black", align = 'mid')
ax.set_xlim(0,5000000000)
ax.set_ylim(0,2000)
ax.set_title('Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(mineableshis['volume'],bins = 5000, edgecolor = "black", align = 'mid')
ax.set_xlim(0,3000000000)
ax.set_ylim(0,2000)
ax.set_title('Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# Plotting Sums too!

# %%
volume_distribution = mineableshis.groupby('name')['volume'].sum().reset_index()
volume_distribution
# Out:
#                 name        volume
# 0            Bitcoin  8.372141e+12
# 1       Bitcoin Cash  9.176241e+10
# 2       Bitcoin Gold  4.842654e+09
# 3         Bitcoin SV  1.966732e+10
# 4            Conflux  3.935445e+10
# 5               Dash  2.687170e+10
# 6             Decred  9.111868e+08
# 7           DigiByte  1.504688e+09
# 8           Dogecoin  2.297730e+11
# 9   Ethereum Classic  9.819152e+10
# 10          Filecoin  7.062464e+10
# 11              Flux  4.961888e+09
# 12            Helium  2.475514e+09
# 13           Horizen  4.551462e+09
# 14            Kadena  2.295060e+09
# 15          Litecoin  2.156843e+11
# 16            Monero  2.869353e+10
# 17    Nervos Network  2.130997e+09
# 18         Ravencoin  8.270445e+09
# 19           Siacoin  3.590231e+09
# 20            Stacks  2.767763e+10
# 21             Zcash  1.528844e+10
# 22           Zilliqa  1.693872e+10

# %%
plt.figure(figsize=(22, 22))
plt.bar(volume_distribution['name'], volume_distribution['volume'])
plt.xlabel('Coin Name')
plt.ylabel('Daily Trading Volume')
plt.title('Daily Trading Volume Distribution of Mineable Coins')
plt.xticks(rotation=45, ha="right")  
plt.tight_layout()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Plotting means too!

# %%
volume_distribution = mineableshis.groupby('name')['volume'].mean().reset_index()
volume_distribution
# Out:
#                 name        volume
# 0            Bitcoin  2.300039e+10
# 1       Bitcoin Cash  2.520945e+08
# 2       Bitcoin Gold  1.330400e+07
# 3         Bitcoin SV  5.403109e+07
# 4            Conflux  1.081166e+08
# 5               Dash  7.382336e+07
# 6             Decred  2.503261e+06
# 7           DigiByte  4.133757e+06
# 8           Dogecoin  6.312444e+08
# 9   Ethereum Classic  2.697569e+08
# 10          Filecoin  1.940237e+08
# 11              Flux  1.363156e+07
# 12            Helium  6.800864e+06
# 13           Horizen  1.250402e+07
# 14            Kadena  6.305110e+06
# 15          Litecoin  5.925393e+08
# 16            Monero  7.882837e+07
# 17    Nervos Network  5.854388e+06
# 18         Ravencoin  2.272100e+07
# 19           Siacoin  9.863271e+06
# 20            Stacks  7.603744e+07
# 21             Zcash  4.200122e+07
# 22           Zilliqa  4.653495e+07

# %%
plt.figure(figsize=(22, 22))
plt.bar(volume_distribution['name'], volume_distribution['volume'])
plt.xlabel('Coin Name')
plt.ylabel('Daily Trading Volume')
plt.title('Daily Trading Volume Distribution of Mineable Coins')
plt.xticks(rotation=45, ha="right")  
plt.tight_layout()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ۴)ماتریس هم بستگی</font>
# </p>

# %% [markdown]
# 16 top coins marketCap corr matrix
#
# Considering that a corr matrix is always symmetric:

# %%
coinhis['Date'] = pd.to_datetime(coinhis['Date'])
df = coinhis.loc[(coinhis['Date'] == '2023-08-31')]
df
# Out:
#           id          name       Date       open        timeHigh       high  \
# 0          1     Synthetix 2023-08-31   1.995610 0 days 02:57:00   2.024010
# 364      365  Decentraland 2023-08-31   0.305262 0 days 01:46:00   0.306325
# 728      729    Bitcoin SV 2023-08-31  32.632200 0 days 01:46:00  33.157800
# 1092    1093        Fantom 2023-08-31   0.211612 0 days 01:49:00   0.215447
# 1456    1457     Injective 2023-08-31   7.115680 0 days 01:49:00   7.304820
# ...      ...           ...        ...        ...             ...        ...
# 68510  68511     THORChain 2023-08-31   1.538020 0 days 01:49:00   1.575070
# 68874  68875           Neo 2023-08-31   7.394270 0 days 01:46:00   7.420980
# 69238  69239    Pax Dollar 2023-08-31   1.000090 0 days 01:48:00   1.001610
# 69602  69603       ApeCoin 2023-08-31   1.474280 0 days 02:57:00   1.497290
# 69966  69967        Render 2023-08-31   1.447070 0 days 01:46:00   1.451050
#
#               timeLow        low      close      volume    marketCap  \
# 0     0 days 02:14:00   1.923430   1.928390  43897700.0  519682000.0
# 364   0 days 07:22:00   0.291472   0.294341  51834000.0  557215000.0
# 728   0 days 01:49:00  31.192000  31.229000  25036200.0  601659000.0
# 1092  0 days 03:59:00   0.200656   0.200656  58585500.0  562498000.0
# 1456  0 days 01:10:00   6.932920   6.992260  30878700.0  585641000.0
# ...               ...        ...        ...         ...          ...
# 68510 0 days 01:10:00   1.475130   1.499050  45611900.0  510432000.0
# 68874 0 days 01:16:00   7.014250   7.068070  22764200.0  498573000.0
# 69238 0 days 01:10:00   0.991954   0.993349   2093420.0  501811000.0
# 69602 0 days 01:10:00   1.418550   1.429130  39179300.0  526769000.0
# 69966 0 days 01:10:00   1.351110   1.372780  22054400.0  510548000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 0        1.928390       2.694910e+08    -0.067185          Red     -0.067220
# 364      0.294341       1.893100e+09    -0.010954          Red     -0.010921
# 728     31.229000       1.926610e+07    -1.400170          Red     -1.403200
# 1092     0.200656       2.803300e+09    -0.010947          Red     -0.010956
# 1456     6.992260       8.375560e+07    -0.123154          Red     -0.123420
# ...           ...                ...          ...          ...           ...
# 68510    1.499050       3.405030e+08    -0.039015          Red     -0.038970
# 68874    7.068070       7.053880e+07    -0.326031          Red     -0.326200
# 69238    0.993349       5.051710e+08    -0.006734          Red     -0.006741
# 69602    1.429130       3.685940e+08    -0.045130          Red     -0.045150
# 69966    1.372780       3.719080e+08    -0.074377          Red     -0.074290
#
#       mc_stats  clusters
# 0          low         0
# 364        low         0
# 728        low         0
# 1092       low         0
# 1456       low         0
# ...        ...       ...
# 68510      low         0
# 68874      low         0
# 69238      low         0
# 69602      low         0
# 69966      low         0
#
# [200 rows x 18 columns]

# %%
df = df.sort_values(['marketCap'], ascending=False).head(16)
l = df.name.to_list()

# %%
H=dict()
for i in l:
    c=np.array(coinhis[coinhis['name']==i]['Price change'].values)
    delta=c[1:]-c[:len(c)-1]
    H[i]=delta
data=pd.DataFrame(H)
data
# Out:
#      Bitcoin  Ethereum   Tether USDt     BNB       XRP  USD Coin  Dogecoin  \
# 0      941.6     35.15  2.340000e-04   4.150  0.005545  0.000110  0.001499
# 1     2053.7    102.03  6.720000e-04  11.212  0.028664 -0.000011  0.003512
# 2    -1608.3    -82.44 -8.970000e-04  -7.780 -0.017405 -0.000196 -0.002692
# 3       64.9     16.22  1.860000e-04   1.627  0.000952  0.000105  0.000040
# 4     -120.2    -17.86  5.700000e-05  -3.956 -0.003108 -0.000088 -0.000521
# ..       ...       ...           ...     ...       ...       ...       ...
# 358  -1432.6   -124.49 -8.000000e-05 -30.232 -0.025969 -0.000210 -0.005907
# 359    803.6     94.79 -4.000000e-05  11.916  0.011921 -0.000216  0.003274
# 360    330.6    -18.56 -2.220446e-16   3.228  0.000679  0.000228  0.001022
# 361   -291.8    -41.08  2.220446e-16  -0.715 -0.003135  0.000010  0.000535
# 362    -18.7     11.54  1.140000e-04  -1.317 -0.000619  0.000130 -0.001802
#
#       Cardano  Solana      TRON  Toncoin       Dai  Polkadot   Polygon  \
# 0    0.003493  0.1516 -0.002788 -0.03173  0.000242   0.12979  0.007408
# 1    0.011838  2.1710  0.002660  0.21120  0.000194   0.20379  0.049648
# 2   -0.001047 -1.4538 -0.002084 -0.21195 -0.000117   0.04713 -0.025287
# 3   -0.001490  0.7360  0.001217  0.05126  0.000200  -0.12572  0.001804
# 4   -0.002613 -0.6187  0.000144 -0.00789 -0.000597   0.02984 -0.005944
# ..        ...     ...       ...      ...       ...       ...       ...
# 358 -0.052296 -3.1350 -0.003257 -0.21631 -0.003329  -0.80845 -0.084950
# 359  0.031978  1.3946  0.001632  0.22664  0.001499   0.47975  0.049819
# 360  0.026759  0.9115  0.000962 -0.20841  0.000150   0.09311  0.017887
# 361  0.003141 -1.1168  0.000122 -0.00899  0.000040  -0.10185  0.012273
# 362 -0.028758 -0.2384 -0.001172  0.00582  0.000333   0.13297 -0.030710
#
#      Litecoin     Shiba Inu
# 0      2.4758 -3.296000e-08
# 1      4.5844  3.497700e-07
# 2     -3.1761  4.629000e-08
# 3      0.1820 -2.334000e-07
# 4     -0.4589 -1.290000e-09
# ..        ...           ...
# 358   -9.2142 -8.590000e-07
# 359    5.6157  3.779000e-07
# 360    1.2432  7.437000e-07
# 361   -1.6609 -3.838000e-07
# 362    4.4190 -2.612000e-07
#
# [363 rows x 16 columns]

# %%
f, AX_1= plt.subplots(figsize=(20,18))
AX_1.set_title('Correlation Matrix for DailyPriceChange in top 16 Coins from marketCap view')
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',ax=AX_1)
# Out:
# <Axes: title={'center': 'Correlation Matrix for DailyPriceChange in top 16 Coins from marketCap view'}>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# ۵)بهار سبز و قرمز!</font>
# </p>

# %% [markdown]
# Filtering spring and plotting!

# %%
rg=coinhis[((coinhis['Date'].dt.month==3)|(coinhis['Date'].dt.month==4)|(coinhis['Date'].dt.month==5))][['name','Date','marketCap','Price change']]
rg
# Out:
#             name       Date    marketCap  Price change
# 92     Synthetix 2023-05-31  605314000.0      -0.07787
# 93     Synthetix 2023-05-30  625608000.0      -0.00724
# 94     Synthetix 2023-05-29  627618000.0      -0.08327
# 95     Synthetix 2023-05-28  649249000.0       0.09127
# 96     Synthetix 2023-05-27  625420000.0      -0.00325
# ...          ...        ...          ...           ...
# 70145     Render 2023-03-05  303961000.0      -0.04166
# 70146     Render 2023-03-04  314285000.0      -0.11861
# 70147     Render 2023-03-03  344414000.0      -0.17080
# 70148     Render 2023-03-02  387738000.0      -0.03216
# 70149     Render 2023-03-01  395948000.0       0.10417
#
# [17900 rows x 4 columns]

# %%
April=list(range(1,31))
May_March=list(range(1,32))
col=[]
for i in [(3,May_March),(4,April),(5,May_March)]:
    for j in i[1]:
        d=rg[(rg['Date'].dt.month==i[0])&(rg['Date'].dt.day==j)]
        n=0.35*len(d)
        if sum(d['Price change']>=0)<n:
            col.extend(rg[(rg['Date']=='2023-{}-{}'.format(i[0],j))&(rg['Price change']>=0)]['name'])
col.sort()
my_dict = {i:col.count(i) for i in col}
v_dict={k: v for k, v in sorted(my_dict.items(), key=lambda item: item[1],reverse=True)}
top10=list(v_dict.keys())[:10]
top10
# Out:
# ['USD Coin',
#  'Tether USDt',
#  'PAX Gold',
#  'Tether Gold',
#  'Dai',
#  'UNUS SED LEO',
#  'USDD',
#  'MX TOKEN',
#  'TrueUSD',
#  'Binance USD']

# %%
o=rg.groupby('name')['marketCap'].sum()
y=[o[i] for i in top10]

# %%
fig , ax = plt.subplots(figsize=(20,10))
ax.bar(top10,y)
ax.set_title('Top 10 in')
ax.set_xlabel('Coin name')
ax.set_ylabel('Total markeCap')
plt.show()

# %% [markdown]
# Zooming again!

# %%
fig , ax = plt.subplots(figsize=(20,10))
ax.bar(top10,y)
ax.set_title('Top 10 in')
ax.set_xlabel('Coin name')
ax.set_ylabel('Total marketCap')
ax.set_ylim(0,4000000000000)
plt.show()

# %%
fig , ax = plt.subplots(figsize=(20,10))
ax.bar(top10,y)
ax.set_title('Top 10 in')
ax.set_xlabel('Coin name')
ax.set_ylabel('Total marketCap')
ax.set_ylim(0,3200000000000)
plt.show()

# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# تخمین
# </font>
# </h1>

# %%
sample=np.random.choice(names,size=40)
sample_mean=[]
sample_std=[]
for i in sample:
    sample_mean.append(np.mean(coinhis[coinhis['name']==i]['volume']))
    sample_std.append(np.std(coinhis[coinhis['name']==i]['volume']))

# %%
sample
# Out:
# array(['THORChain', 'Holo', 'Render', 'Pundi X (New)', 'Klaytn',
#        'Compound', 'Holo', 'Kava', 'KuCoin Token', 'Astar', 'Moonbeam',
#        'Sui', 'Aragon', 'Alchemy Pay', 'Ravencoin', 'Everscale',
#        'Shiba Inu', 'Livepeer', 'Amp', 'Nano', 'Nano', 'Nexo',
#        'GateToken', 'Dash', 'Trust Wallet Token', 'Nano', 'Status',
#        'USDD', 'Bitcoin', 'Monero', 'Injective', 'Arweave', 'Ravencoin',
#        'SKALE', 'Ethereum Name Service', 'PAX Gold', 'TerraClassicUSD',
#        'Solana', 'DigiByte', 'Kadena'], dtype='<U24')

# %%
lower=[]
upper=[]
for i,j in enumerate(sample):
    t_score = sp.stats.t.ppf((1 + 0.98) / 2, df=sum(coinhis['name']==j)- 1)
    margin_of_error = t_score * (sample_std[i] / np.sqrt(sum(coinhis['name']==j)))
    lower.append( sample_mean[i] - margin_of_error)
    upper.append (sample_mean[i] + margin_of_error)

# %%
for i,j in enumerate(sample):
    print(j,'will be in (',lower[i],',',upper[i],') with 98 percents confidence')
# Out:
# THORChain will be in ( 34364682.16432806 , 41015133.22028733 ) with 98 percents confidence
# Holo will be in ( 16772701.678951409 , 20664692.99137826 ) with 98 percents confidence
# Render will be in ( 62692044.50229886 , 81989674.89330554 ) with 98 percents confidence
# Pundi X (New) will be in ( 9036782.991480602 , 17963642.06895896 ) with 98 percents confidence
# Klaytn will be in ( 32247406.655730214 , 44832167.08053352 ) with 98 percents confidence
# Compound will be in ( 36282138.31174475 , 46808823.66627723 ) with 98 percents confidence
# Holo will be in ( 16772701.678951409 , 20664692.99137826 ) with 98 percents confidence
# Kava will be in ( 30980083.709164146 , 42398638.32380288 ) with 98 percents confidence
# KuCoin Token will be in ( 1475228.8994269927 , 1811662.842331249 ) with 98 percents confidence
# Astar will be in ( 8415682.178501291 , 12571419.436883325 ) with 98 percents confidence
# Moonbeam will be in ( 7107188.396751234 , 8875870.284567447 ) with 98 percents confidence
# Sui will be in ( 156792337.4324265 , 235245484.0551768 ) with 98 percents confidence
# Aragon will be in ( 11515571.790383967 , 14025713.209616033 ) with 98 percents confidence
# Alchemy Pay will be in ( 26093360.33997982 , 39136063.066613585 ) with 98 percents confidence
# Ravencoin will be in ( 16411706.649264932 , 29030297.52655924 ) with 98 percents confidence
# Everscale will be in ( 4426978.112991009 , 5498056.018877123 ) with 98 percents confidence
# Shiba Inu will be in ( 220896622.51908302 , 276148063.1952027 ) with 98 percents confidence
# Livepeer will be in ( 10065139.327297628 , 16177139.299075998 ) with 98 percents confidence
# Amp will be in ( 7550415.789003026 , 11121332.123084888 ) with 98 percents confidence
# Nano will be in ( 1630526.556362776 , 3852488.1634174436 ) with 98 percents confidence
# Nano will be in ( 1630526.556362776 , 3852488.1634174436 ) with 98 percents confidence
# Nexo will be in ( 5821821.9053801 , 7107688.31440012 ) with 98 percents confidence
# GateToken will be in ( 1335811.3102255696 , 1561744.5688953097 ) with 98 percents confidence
# Dash will be in ( 70157712.98642956 , 77489015.03554846 ) with 98 percents confidence
# Trust Wallet Token will be in ( 27000332.185696397 , 41091295.34177613 ) with 98 percents confidence
# Nano will be in ( 1630526.556362776 , 3852488.1634174436 ) with 98 percents confidence
# Status will be in ( 5214403.629054887 , 10479865.283033025 ) with 98 percents confidence
# USDD will be in ( 30032967.89038129 , 38136011.94478354 ) with 98 percents confidence
# Bitcoin will be in ( 21355211676.33087 , 24645560411.581215 ) with 98 percents confidence
# Monero will be in ( 74780828.39269403 , 82875912.81609717 ) with 98 percents confidence
# Injective will be in ( 42311464.48110129 , 52896559.09032728 ) with 98 percents confidence
# Arweave will be in ( 18469117.702858455 , 25558175.886182643 ) with 98 percents confidence
# Ravencoin will be in ( 16411706.649264932 , 29030297.52655924 ) with 98 percents confidence
# SKALE will be in ( 9120686.450543407 , 12677859.978028022 ) with 98 percents confidence
# Ethereum Name Service will be in ( 33371317.71774929 , 41493973.985547416 ) with 98 percents confidence
# PAX Gold will be in ( 9933419.012455223 , 12842185.273259064 ) with 98 percents confidence
# TerraClassicUSD will be in ( 24018503.33880034 , 37131301.71614471 ) with 98 percents confidence
# Solana will be in ( 563194716.97139 , 706645645.6659727 ) with 98 percents confidence
# DigiByte will be in ( 3631020.300496003 , 4636493.578624875 ) with 98 percents confidence
# Kadena will be in ( 5682437.621103251 , 6927781.7195560895 ) with 98 percents confidence

# %%
# Just for some reassurance!
cr = coinhis[coinhis['name'] == 'Solana']
cr['volume'].mean(), sp.stats.norm.interval(0.98, cr['volume'].mean(), cr['volume'].std()/np.sqrt(364))
# Out:
# (634920181.3186814, (563413096.6040759, 706427266.0332868))

# %%
sample_mean = np.array(sample_mean)

# %%
sample_mean.mean(), sample_mean.std()
# Out:
# (622777106.8470433, 3584833798.4551544)

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(sample_mean,bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Means Plot')
ax.set_xlabel('Means')
ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# They are not normally distributed!

# %% [markdown]
# Due to big numbers rule we expected it to be normally distributed though!

# %% [markdown]
# For conducting a CI we will try to make our data normal using boxcox transformation!

# %%
b, lmbda = sp.stats.boxcox(sample_mean)
b
# Out:
# array([4.78519196, 4.76336971, 4.802914  , 4.7520681 , 4.78583759,
#        4.78799055, 4.76336971, 4.78440906, 4.65816368, 4.74282943,
#        4.73229554, 4.82585745, 4.75007127, 4.78093281, 4.76972485,
#        4.71240898, 4.83066918, 4.75104724, 4.73837983, 4.68479618,
#        4.68479618, 4.72368347, 4.65116634, 4.80342867, 4.78221052,
#        4.68479618, 4.73156937, 4.78224415, 4.88928466, 4.80507849,
#        4.79181053, 4.76870454, 4.76972485, 4.74425087, 4.78499307,
#        4.74588025, 4.77899014, 4.84757276, 4.70425767, 4.72264314])

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(b,bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Means Plot')
ax.set_xlabel('Means')
ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# Testing normality:

# %%
from scipy.stats import shapiro
stat, p = shapiro(b)
p
# Out:
# 0.6498748064041138

# %% [markdown]
# We can confidently say that our transformed data is normal!

# %%
b
# Out:
# array([4.78519196, 4.76336971, 4.802914  , 4.7520681 , 4.78583759,
#        4.78799055, 4.76336971, 4.78440906, 4.65816368, 4.74282943,
#        4.73229554, 4.82585745, 4.75007127, 4.78093281, 4.76972485,
#        4.71240898, 4.83066918, 4.75104724, 4.73837983, 4.68479618,
#        4.68479618, 4.72368347, 4.65116634, 4.80342867, 4.78221052,
#        4.68479618, 4.73156937, 4.78224415, 4.88928466, 4.80507849,
#        4.79181053, 4.76870454, 4.76972485, 4.74425087, 4.78499307,
#        4.74588025, 4.77899014, 4.84757276, 4.70425767, 4.72264314])

# %%
interval = sp.stats.norm.interval(0.98, loc = b.mean(), scale = b.std())
interval
# Out:
# (4.6459212510651575, 4.874049398581645)

# %% [markdown]
# 98% of our data in a transformed way must be in the given interval!

# %% [markdown]
# We can say, to calculate a confidence interval of 98% we should transform our data to a normal one.
#
# Then we will use the transformed data to calculate the interval and given the current data, our interval would be as shown.

# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آزمون فرض
# </font>
# </h1>

# %% [markdown]
# Hypothesis Test One

# %%
coinhis['weekday'] = coinhis['Date'].dt.day_name()
coinhis
# Out:
#           id       name       Date      open        timeHigh      high  \
# 0          1  Synthetix 2023-08-31  1.995610 0 days 02:57:00  2.024010
# 1          2  Synthetix 2023-08-30  2.060950 0 days 00:55:00  2.084900
# 2          3  Synthetix 2023-08-29  2.080950 0 days 04:46:00  2.137080
# 3          4  Synthetix 2023-08-28  2.107940 0 days 02:36:00  2.139600
# 4          5  Synthetix 2023-08-27  2.071460 0 days 06:44:00  2.148910
# ...      ...        ...        ...       ...             ...       ...
# 70325  70326     Render 2022-09-06  0.500139 0 days 02:28:00  0.507269
# 70326  70327     Render 2022-09-05  0.516513 0 days 00:07:00  0.520092
# 70327  70328     Render 2022-09-04  0.509291 0 days 03:07:00  0.518565
# 70328  70329     Render 2022-09-03  0.520313 0 days 00:50:00  0.521055
# 70329  70330     Render 2022-09-02  0.523143 0 days 05:16:00  0.539434
#
#               timeLow       low     close      volume    marketCap  \
# 0     0 days 02:14:00  1.923430  1.928390  43897700.0  519682000.0
# 1     0 days 03:59:00  1.995570  1.995570  31366400.0  537271000.0
# 2     0 days 00:40:00  2.037480  2.060970  45715400.0  554878000.0
# 3     0 days 01:46:00  2.079480  2.081030  23323500.0  560049000.0
# 4     0 days 00:00:00  2.071460  2.107940  21101900.0  567291000.0
# ...               ...       ...       ...         ...          ...
# 70325 0 days 00:13:00  0.469257  0.469789   9924320.0  119232000.0
# 70326 0 days 00:49:00  0.484872  0.500219  10377500.0  126955000.0
# 70327 0 days 08:08:00  0.497843  0.516505   4796500.0  131088000.0
# 70328 0 days 07:55:00  0.501718  0.509214   4426980.0  129238000.0
# 70329 0 days 09:40:00  0.509584  0.520306   9301720.0  132053000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 0        1.928390        269491000.0    -0.067185          Red     -0.067220
# 1        1.995570        269232000.0    -0.065396          Red     -0.065380
# 2        2.060970        269232000.0    -0.020060          Red     -0.019980
# 3        2.081030        269121000.0    -0.026909          Red     -0.026910
# 4        2.107940        269121000.0     0.036344        Green      0.036480
# ...           ...                ...          ...          ...           ...
# 70325    0.469789        253799000.0    -0.030430          Red     -0.030350
# 70326    0.500219        253799000.0    -0.016286          Red     -0.016294
# 70327    0.516505        253799000.0     0.007291        Green      0.007214
# 70328    0.509214        253799000.0    -0.011092          Red     -0.011099
# 70329    0.520306        253799000.0     0.000000         Gray     -0.002837
#
#       mc_stats  clusters    weekday
# 0          low         0   Thursday
# 1          low         0  Wednesday
# 2          low         0    Tuesday
# 3          low         0     Monday
# 4          low         0     Sunday
# ...        ...       ...        ...
# 70325      low         0    Tuesday
# 70326      low         0     Monday
# 70327      low         0     Sunday
# 70328      low         0   Saturday
# 70329      low         0     Friday
#
# [70330 rows x 19 columns]

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(coinhis['volume'],bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# Volume is not normal therefore no T-test!

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(coinhis['Price change'],bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Price Plot')
ax.set_xlabel('Price')
ax.set_ylabel('Frequency')
plt.show()

# %%
sp.stats.kurtosis(coinhis['Price change'], bias=True)
# Out:
# 650.0719878094325

# %% [markdown]
# The 3+ kurtosis states that our data is not normal and it's a leptokurtic distributed data, but due to being normal-like, T-testing would be available.

# %%
from scipy.stats import shapiro
stat, p = shapiro(coinhis['Price change'])
p
# Out:
# c:\Users\ROG\anaconda3\envs\MLB\lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 0.0

# %% [markdown]
# There is no way that this is a normally distributed data!

# %%
weekends = coinhis[(coinhis['weekday']=='Thursday') | (coinhis['weekday']=='Friday') | (coinhis['weekday']=='Saturday')]
weekends
# Out:
#           id       name       Date      open        timeHigh      high  \
# 0          1  Synthetix 2023-08-31  1.995610 0 days 02:57:00  2.024010
# 5          6  Synthetix 2023-08-26  2.062420 0 days 05:06:00  2.082830
# 6          7  Synthetix 2023-08-25  2.074430 0 days 00:22:00  2.075320
# 7          8  Synthetix 2023-08-24  2.138410 0 days 07:25:00  2.147890
# 12        13  Synthetix 2023-08-19  2.181630 0 days 07:06:00  2.245450
# ...      ...        ...        ...       ...             ...       ...
# 70321  70322     Render 2022-09-10  0.564239 0 days 08:04:00  0.627566
# 70322  70323     Render 2022-09-09  0.550511 0 days 02:43:00  0.569030
# 70323  70324     Render 2022-09-08  0.507117 0 days 08:05:00  0.622047
# 70328  70329     Render 2022-09-03  0.520313 0 days 00:50:00  0.521055
# 70329  70330     Render 2022-09-02  0.523143 0 days 05:16:00  0.539434
#
#               timeLow       low     close      volume    marketCap  \
# 0     0 days 02:14:00  1.923430  1.928390  43897700.0  519682000.0
# 5     0 days 00:55:00  2.052110  2.071590  14078800.0  557510000.0
# 6     0 days 07:49:00  2.020170  2.062360  32694900.0  555025000.0
# 7     0 days 01:00:00  2.046850  2.074440  26242400.0  558277000.0
# 12    0 days 07:12:00  2.171880  2.240550  17961000.0  602595000.0
# ...               ...       ...       ...         ...          ...
# 70321 0 days 01:09:00  0.560060  0.582239  24590000.0  147772000.0
# 70322 0 days 07:44:00  0.535818  0.564269  19865800.0  143211000.0
# 70323 0 days 03:13:00  0.491250  0.550873  44263500.0  139811000.0
# 70328 0 days 07:55:00  0.501718  0.509214   4426980.0  129238000.0
# 70329 0 days 09:40:00  0.509584  0.520306   9301720.0  132053000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 0        1.928390        269491000.0    -0.067185          Red     -0.067220
# 5        2.071590        269121000.0     0.009235        Green      0.009170
# 6        2.062360        269121000.0    -0.012086          Red     -0.012070
# 7        2.074440        269121000.0    -0.063833          Red     -0.063970
# 12       2.240550        268950000.0     0.059076        Green      0.058920
# ...           ...                ...          ...          ...           ...
# 70321    0.582239        253799000.0     0.017970        Green      0.018000
# 70322    0.564269        253799000.0     0.013396        Green      0.013758
# 70323    0.550873        253799000.0     0.043774        Green      0.043756
# 70328    0.509214        253799000.0    -0.011092          Red     -0.011099
# 70329    0.520306        253799000.0     0.000000         Gray     -0.002837
#
#       mc_stats  clusters   weekday
# 0          low         0  Thursday
# 5          low         0  Saturday
# 6          low         0    Friday
# 7          low         0  Thursday
# 12         low         0  Saturday
# ...        ...       ...       ...
# 70321      low         0  Saturday
# 70322      low         0    Friday
# 70323      low         0  Thursday
# 70328      low         0  Saturday
# 70329      low         0    Friday
#
# [30142 rows x 19 columns]

# %%
weekdays = coinhis[(coinhis['weekday']=='Sunday') | (coinhis['weekday']=='Monday') | (coinhis['weekday']=='Tuesday')]
weekdays
# Out:
#           id       name       Date      open        timeHigh      high  \
# 2          3  Synthetix 2023-08-29  2.080950 0 days 04:46:00  2.137080
# 3          4  Synthetix 2023-08-28  2.107940 0 days 02:36:00  2.139600
# 4          5  Synthetix 2023-08-27  2.071460 0 days 06:44:00  2.148910
# 9         10  Synthetix 2023-08-22  2.094780 0 days 06:59:00  2.114860
# 10        11  Synthetix 2023-08-21  2.149070 0 days 03:09:00  2.150930
# ...      ...        ...        ...       ...             ...       ...
# 70319  70320     Render 2022-09-12  0.563672 0 days 04:08:00  0.583103
# 70320  70321     Render 2022-09-11  0.582062 0 days 01:13:00  0.600198
# 70325  70326     Render 2022-09-06  0.500139 0 days 02:28:00  0.507269
# 70326  70327     Render 2022-09-05  0.516513 0 days 00:07:00  0.520092
# 70327  70328     Render 2022-09-04  0.509291 0 days 03:07:00  0.518565
#
#               timeLow       low     close      volume    marketCap  \
# 2     0 days 00:40:00  2.037480  2.060970  45715400.0  554878000.0
# 3     0 days 01:46:00  2.079480  2.081030  23323500.0  560049000.0
# 4     0 days 00:00:00  2.071460  2.107940  21101900.0  567291000.0
# 9     0 days 01:41:00  2.009590  2.067720  24249200.0  556154000.0
# 10    0 days 01:13:00  2.084880  2.094920  29950200.0  563439000.0
# ...               ...       ...       ...         ...          ...
# 70319 0 days 03:46:00  0.540043  0.569006  12824700.0  144413000.0
# 70320 0 days 02:01:00  0.553060  0.563641  13357200.0  143051000.0
# 70325 0 days 00:13:00  0.469257  0.469789   9924320.0  119232000.0
# 70326 0 days 00:49:00  0.484872  0.500219  10377500.0  126955000.0
# 70327 0 days 08:08:00  0.497843  0.516505   4796500.0  131088000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 2        2.060970        269232000.0    -0.020060          Red     -0.019980
# 3        2.081030        269121000.0    -0.026909          Red     -0.026910
# 4        2.107940        269121000.0     0.036344        Green      0.036480
# 9        2.067720        268970000.0    -0.027208          Red     -0.027060
# 10       2.094920        268955000.0    -0.054175          Red     -0.054150
# ...           ...                ...          ...          ...           ...
# 70319    0.569006        253799000.0     0.005365        Green      0.005334
# 70320    0.563641        253799000.0    -0.018599          Red     -0.018421
# 70325    0.469789        253799000.0    -0.030430          Red     -0.030350
# 70326    0.500219        253799000.0    -0.016286          Red     -0.016294
# 70327    0.516505        253799000.0     0.007291        Green      0.007214
#
#       mc_stats  clusters  weekday
# 2          low         0  Tuesday
# 3          low         0   Monday
# 4          low         0   Sunday
# 9          low         0  Tuesday
# 10         low         0   Monday
# ...        ...       ...      ...
# 70319      low         0   Monday
# 70320      low         0   Sunday
# 70325      low         0  Tuesday
# 70326      low         0   Monday
# 70327      low         0   Sunday
#
# [30136 rows x 19 columns]

# %% [markdown]
# Dynamism of a market is a factor of its inner daily changes or its volume in every time portion
#
# We will test each interpretation.
#
# Price change and Volume will be tested using a manwhitney U-test and boxcox transformation if needed.

# %% [markdown]
# Prices:
#
# Floodgate through equality
#
# x: weekends
#
# y: weekdays
#
# H0 : μx = μy
#
# H1 : μx != μy

# %%
from scipy.stats import mannwhitneyu
stat, p_value = mannwhitneyu(weekends['Price change'], weekdays['Price change'])
p_value
# Out:
# 0.9030782775772508

# %% [markdown]
# Confidentally we can say that week days and price changes are independant and therefore there is no significant relation between them.

# %% [markdown]
# Volumes:
#
# Floodgate through equality
#
# x: weekends
#
# y: weekdays
#
# H0 : μx = μy
#
# H1 : μx != μy

# %%
from scipy.stats import mannwhitneyu
stat, p_value = mannwhitneyu(weekends['volume'], weekdays['volume'])
p_value
# Out:
# 0.7034366803570782

# %% [markdown]
# Using manwhitney U-test we can assume that week day has no direct effect on market's volume.

# %% [markdown]
# Hence, volume and price change has no values of induction and we can say using volume or price change, weekdays and weekends won't differ significantly in dynamicity.

# %% [markdown]
# We will try to make the data normal by IQR method.

# %%
Q1 = coinhis['Price change'].quantile(0.25)
Q3 = coinhis['Price change'].quantile(0.75)
IQR = Q3 - Q1
m = coinhis['Price change']
m = m[(m <= Q3 + IQR*1.5) & (m >= Q1 - IQR*1.5)]
m
# Out:
# 2       -0.019980
# 3       -0.026910
# 4        0.036480
# 5        0.009170
# 6       -0.012070
#            ...
# 70325   -0.030350
# 70326   -0.016294
# 70327    0.007214
# 70328   -0.011099
# 70329   -0.002837
# Name: Price change, Length: 47520, dtype: float64

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(m,bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('IQRPrice Plot')
ax.set_xlabel('Price')
ax.set_ylabel('Frequency')
plt.show()

# %%
from scipy.stats import shapiro
stat, p = shapiro(m)
p
# Out:
# c:\Users\ROG\anaconda3\envs\MLB\lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 0.0

# %% [markdown]
# Still not normal!

# %% [markdown]
# Trying Yeo-Johnson transformation

# %%
y = sp.stats.yeojohnson(m)
y
# Out:
# (array([-0.01946688, -0.02598678,  0.03826699, ...,  0.00728278,
#         -0.01093897, -0.00282644]),
#  3.633023372476427)

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(y[0],bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Yeo Price Plot')
ax.set_xlabel('Price')
ax.set_ylabel('Frequency')
plt.show()

# %%
from scipy.stats import shapiro
stat, p = shapiro(y[0])
p
# Out:
# 0.0

# %% [markdown]
# It won't be normal any way!

# %% [markdown]
# Any of the transformations didn't help us to make our data normal!

# %% [markdown]
# Trying to convert it using BoxCox, we will need a positive data.
#
# We will try price change abs instead but due to number of zeros it won't help.
#
# We will consider price changes as abs and run our tests again.

# %%
dff = coinhis[['weekday', 'Price change']]
dff['Price change'] = abs(dff['Price change'])
dff
# Out:
# C:\Users\ROG\AppData\Local\Temp\ipykernel_3780\497230489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['Price change'] = abs(dff['Price change'])
#          weekday  Price change
# 0       Thursday      0.067220
# 1      Wednesday      0.065380
# 2        Tuesday      0.019980
# 3         Monday      0.026910
# 4         Sunday      0.036480
# ...          ...           ...
# 70325    Tuesday      0.030350
# 70326     Monday      0.016294
# 70327     Sunday      0.007214
# 70328   Saturday      0.011099
# 70329     Friday      0.002837
#
# [70330 rows x 2 columns]

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(dff['Price change'],bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Price Plot')
ax.set_xlabel('Price')
ax.set_ylabel('Frequency')
plt.show()

# %%
we = dff[(dff['weekday']=='Thursday') | (dff['weekday']=='Friday') | (dff['weekday']=='Saturday')]

# %%
wd = dff[(dff['weekday']=='Sunday') | (dff['weekday']=='Monday') | (dff['weekday']=='Tuesday')]

# %%
stat, p_value = mannwhitneyu(we['Price change'], wd['Price change'])
p_value
# Out:
# 0.043852315690252636

# %% [markdown]
# If we are not being too strict in precesion, we can say price change abs can say something!
#
# Let's dig into it:

# %%
cf = dff[dff['Price change']!=0]
cf
# Out:
#          weekday  Price change
# 0       Thursday      0.067220
# 1      Wednesday      0.065380
# 2        Tuesday      0.019980
# 3         Monday      0.026910
# 4         Sunday      0.036480
# ...          ...           ...
# 70325    Tuesday      0.030350
# 70326     Monday      0.016294
# 70327     Sunday      0.007214
# 70328   Saturday      0.011099
# 70329     Friday      0.002837
#
# [70294 rows x 2 columns]

# %%
c, lmbda = sp.stats.boxcox(cf['Price change'])
c
# Out:
# array([-2.58228067, -2.60764303, -3.66941568, ..., -4.54900753,
#        -4.1806395 , -5.32912579])

# %%
cf = pd.concat([cf,pd.DataFrame(c)], axis =1)
cf = cf.rename(columns={0:'BC'})
cf
# Out:
#          weekday  Price change        BC
# 0       Thursday       0.06722 -2.582281
# 1      Wednesday       0.06538 -2.607643
# 2        Tuesday       0.01998 -3.669416
# 3         Monday       0.02691 -3.406642
# 4         Sunday       0.03648 -3.135434
# ...          ...           ...       ...
# 57246        NaN           NaN -7.013501
# 57400        NaN           NaN -7.437581
# 63074        NaN           NaN -3.709399
# 67913        NaN           NaN  0.696059
# 69999        NaN           NaN -3.788541
#
# [70330 rows x 3 columns]

# %%
cf = cf[:70258]
cf
# Out:
#          weekday  Price change        BC
# 0       Thursday      0.067220 -2.582281
# 1      Wednesday      0.065380 -2.607643
# 2        Tuesday      0.019980 -3.669416
# 3         Monday      0.026910 -3.406642
# 4         Sunday      0.036480 -3.135434
# ...          ...           ...       ...
# 70289  Wednesday      0.007209 -3.299741
# 70290    Tuesday      0.027121 -3.847891
# 70291     Monday      0.015861 -4.549008
# 70292     Sunday      0.010157 -4.180639
# 70293   Saturday      0.013758 -5.329126
#
# [70258 rows x 3 columns]

# %%
we = cf[(cf['weekday']=='Thursday') | (cf['weekday']=='Friday') | (cf['weekday']=='Saturday')]

# %%
wd = cf[(cf['weekday']=='Sunday') | (cf['weekday']=='Monday') | (cf['weekday']=='Tuesday')]

# %% [markdown]
# Prices:
#
# Floodgate through equality
#
# x: weekends
#
# y: weekdays
#
# H0 : μx < μy
#
# H1 : μx >= μy

# %%
xbar = we['Price change'].mean()
ybar = wd['Price change'].mean()
stdx = we['Price change'].std()
stdy = wd['Price change'].std()
U = (xbar - ybar) / np.sqrt((stdx**2/len(we)) + (stdy**2/len(wd)))
A = (-np.inf, sp.stats.norm.ppf(.95))
U >= A[0] and U <= A[1]
# Out:
# True

# %%
#*2 because of being two way!
p_value = sp.stats.norm.sf(abs(U))*2
p_value
# Out:
# 0.5643253899324769

# %% [markdown]
# As you can see, considering abs of Price change we can say that weekdays are better for trading!

# %% [markdown]
# Hypothesis Test Two

# %%
Group1 = coinhis[(coinhis['name']=='Bitcoin')|(coinhis['name']=='Ethereum')|(coinhis['name']=='Tether USDt')]['volume']
Group1
# Out:
# 19817    2.730240e+10
# 19818    2.271870e+10
# 19819    3.925720e+10
# 19820    1.816020e+10
# 19821    1.207260e+10
#              ...
# 20904    4.340400e+10
# 20905    2.881350e+10
# 20906    2.524590e+10
# 20907    2.361310e+10
# 20908    2.912400e+10
# Name: volume, Length: 1092, dtype: float64

# %%
Group2 = coinhis[(coinhis['name']!='Bitcoin')&(coinhis['name']!='Ethereum')&(coinhis['name']!='Tether USDt')]['volume']
Group2
# Out:
# 0        43897700.0
# 1        31366400.0
# 2        45715400.0
# 3        23323500.0
# 4        21101900.0
#             ...
# 70325     9924320.0
# 70326    10377500.0
# 70327     4796500.0
# 70328     4426980.0
# 70329     9301720.0
# Name: volume, Length: 69238, dtype: float64

# %% [markdown]
# We know that volume has a non-normal distribution therefore a U-test is needed

# %% [markdown]
# Floodgate through equality
#
# x: BTC, ETH, USDT
#
# y: Others
#
# H0 : μx = μy
#
# H1 : μx != μy
#
# It must be considered that a U-test only talks about having a relation not the state of it.

# %%
from scipy.stats import mannwhitneyu
stat, p_value = mannwhitneyu(Group1, Group2)
p_value
# Out:
# 0.0

# %% [markdown]
# Using the U-test it is stated that coins group has direct effect on their volume.
#
# For the state of relation we will use boxcox transformation and T-test afterwards

# %%
dfx, lmbda = sp.stats.boxcox(coinhis['volume'])
coinhis = pd.concat([coinhis,pd.DataFrame(dfx)], axis =1)
coinhis = coinhis.rename(columns={0:'BC'})
coinhis
# Out:
#           id       name       Date      open        timeHigh      high  \
# 0          1  Synthetix 2023-08-31  1.995610 0 days 02:57:00  2.024010
# 1          2  Synthetix 2023-08-30  2.060950 0 days 00:55:00  2.084900
# 2          3  Synthetix 2023-08-29  2.080950 0 days 04:46:00  2.137080
# 3          4  Synthetix 2023-08-28  2.107940 0 days 02:36:00  2.139600
# 4          5  Synthetix 2023-08-27  2.071460 0 days 06:44:00  2.148910
# ...      ...        ...        ...       ...             ...       ...
# 70325  70326     Render 2022-09-06  0.500139 0 days 02:28:00  0.507269
# 70326  70327     Render 2022-09-05  0.516513 0 days 00:07:00  0.520092
# 70327  70328     Render 2022-09-04  0.509291 0 days 03:07:00  0.518565
# 70328  70329     Render 2022-09-03  0.520313 0 days 00:50:00  0.521055
# 70329  70330     Render 2022-09-02  0.523143 0 days 05:16:00  0.539434
#
#               timeLow       low     close      volume    marketCap  \
# 0     0 days 02:14:00  1.923430  1.928390  43897700.0  519682000.0
# 1     0 days 03:59:00  1.995570  1.995570  31366400.0  537271000.0
# 2     0 days 00:40:00  2.037480  2.060970  45715400.0  554878000.0
# 3     0 days 01:46:00  2.079480  2.081030  23323500.0  560049000.0
# 4     0 days 00:00:00  2.071460  2.107940  21101900.0  567291000.0
# ...               ...       ...       ...         ...          ...
# 70325 0 days 00:13:00  0.469257  0.469789   9924320.0  119232000.0
# 70326 0 days 00:49:00  0.484872  0.500219  10377500.0  126955000.0
# 70327 0 days 08:08:00  0.497843  0.516505   4796500.0  131088000.0
# 70328 0 days 07:55:00  0.501718  0.509214   4426980.0  129238000.0
# 70329 0 days 09:40:00  0.509584  0.520306   9301720.0  132053000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 0        1.928390        269491000.0    -0.067185          Red     -0.067220
# 1        1.995570        269232000.0    -0.065396          Red     -0.065380
# 2        2.060970        269232000.0    -0.020060          Red     -0.019980
# 3        2.081030        269121000.0    -0.026909          Red     -0.026910
# 4        2.107940        269121000.0     0.036344        Green      0.036480
# ...           ...                ...          ...          ...           ...
# 70325    0.469789        253799000.0    -0.030430          Red     -0.030350
# 70326    0.500219        253799000.0    -0.016286          Red     -0.016294
# 70327    0.516505        253799000.0     0.007291        Green      0.007214
# 70328    0.509214        253799000.0    -0.011092          Red     -0.011099
# 70329    0.520306        253799000.0     0.000000         Gray     -0.002837
#
#       mc_stats  clusters    weekday        BC
# 0          low         0   Thursday  7.550515
# 1          low         0  Wednesday  7.505149
# 2          low         0    Tuesday  7.555873
# 3          low         0     Monday  7.463682
# 4          low         0     Sunday  7.449351
# ...        ...       ...        ...       ...
# 70325      low         0    Tuesday  7.335872
# 70326      low         0     Monday  7.342866
# 70327      low         0     Sunday  7.216780
# 70328      low         0   Saturday  7.203030
# 70329      low         0     Friday  7.325659
#
# [70330 rows x 20 columns]

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(dfx,bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('BCed Volume Plot')
ax.set_xlabel('Volume')
ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# As it shows, our new volume column is a semi-normal one; allowing us to use T-tests!

# %%
Group1x = coinhis[(coinhis['name']=='Bitcoin')|(coinhis['name']=='Ethereum')|(coinhis['name']=='Tether USDt')]['BC']
Group1x
# Out:
# 19817    8.152447
# 19818    8.140707
# 19819    8.174930
# 19820    8.126061
# 19821    8.098370
#            ...
# 20904    8.180983
# 20905    8.155842
# 20906    8.147475
# 20907    8.143194
# 20908    8.156515
# Name: BC, Length: 1092, dtype: float64

# %%
Group2x = coinhis[(coinhis['name']!='Bitcoin')&(coinhis['name']!='Ethereum')&(coinhis['name']!='Tether USDt')]['BC']
Group2x
# Out:
# 0        7.550515
# 1        7.505149
# 2        7.555873
# 3        7.463682
# 4        7.449351
#            ...
# 70325    7.335872
# 70326    7.342866
# 70327    7.216780
# 70328    7.203030
# 70329    7.325659
# Name: BC, Length: 69238, dtype: float64

# %% [markdown]
# Because of different sample sizes we will use a Welch's T-test.

# %%
sp.stats.ttest_ind(Group1x, Group2x, equal_var = False)
# Out:
# TtestResult(statistic=386.7352552907334, pvalue=0.0, df=2047.5636194443384)

# %% [markdown]
# Considering that, we will know that the two groups have different means.

# %% [markdown]
# Now to find the status of relation we can conduct a normal T-test.
#
# Note: Normat T-test without the result of the Welch test has no value of induction, but when they are integrated; it has some context!

# %% [markdown]
# x: Others
#
# y: BTC, ETH, USDT
#
# H0 : μx < μy
#
# H1 : μx >= μy
#
# Statistic = (xbar - ybar) / sqrt(stdx^2/nx + stdy^2/ny)
#
# Acceptence interval = (-inf, k[α])
#
# If Statistic in Acceptence, Null hypothesis

# %%
xbar = Group2x.mean()
ybar = Group1x.mean()
stdx = Group2x.std()
stdy = Group1x.std()

# %%
S = (xbar - ybar) / np.sqrt((stdx**2/len(Group2x)) + (stdy**2/len(Group1x)))
A = (-np.inf, sp.stats.norm.ppf(.99))

# %%
S >= A[0] and S <= A[1]
# Out:
# True

# %% [markdown]
# It will be accepted that the mentioned coins has an strictly higher volume for 0.01 and any other higher significance level!

# %% [markdown]
# Additional Hypo test

# %%
weekends = coinhis[(coinhis['weekday']=='Saturday') | (coinhis['weekday']=='Sunday')]
weekends
# Out:
#           id       name       Date      open        timeHigh      high  \
# 4          5  Synthetix 2023-08-27  2.071460 0 days 06:44:00  2.148910
# 5          6  Synthetix 2023-08-26  2.062420 0 days 05:06:00  2.082830
# 11        12  Synthetix 2023-08-20  2.240440 0 days 08:03:00  2.259000
# 12        13  Synthetix 2023-08-19  2.181630 0 days 07:06:00  2.245450
# 18        19  Synthetix 2023-08-13  2.544360 0 days 00:03:00  2.545740
# ...      ...        ...        ...       ...             ...       ...
# 70314  70315     Render 2022-09-17  0.462705 0 days 00:56:00  0.486955
# 70320  70321     Render 2022-09-11  0.582062 0 days 01:13:00  0.600198
# 70321  70322     Render 2022-09-10  0.564239 0 days 08:04:00  0.627566
# 70327  70328     Render 2022-09-04  0.509291 0 days 03:07:00  0.518565
# 70328  70329     Render 2022-09-03  0.520313 0 days 00:50:00  0.521055
#
#               timeLow       low     close      volume    marketCap  \
# 4     0 days 00:00:00  2.071460  2.107940  21101900.0  567291000.0
# 5     0 days 00:55:00  2.052110  2.071590  14078800.0  557510000.0
# 11    0 days 03:18:00  2.146170  2.149100  23446800.0  577999000.0
# 12    0 days 07:12:00  2.171880  2.240550  17961000.0  602595000.0
# 18    0 days 06:56:00  2.483330  2.500200  24866300.0  671647000.0
# ...               ...       ...       ...         ...          ...
# 70314 0 days 02:00:00  0.457475  0.482442  17456000.0  122443000.0
# 70320 0 days 02:01:00  0.553060  0.563641  13357200.0  143051000.0
# 70321 0 days 01:09:00  0.560060  0.582239  24590000.0  147772000.0
# 70327 0 days 08:08:00  0.497843  0.516505   4796500.0  131088000.0
# 70328 0 days 07:55:00  0.501718  0.509214   4426980.0  129238000.0
#
#        DailyPrice  CirculatingSupply  DailyChange ChangeStatus  Price change  \
# 4        2.107940        269121000.0     0.036344        Green      0.036480
# 5        2.071590        269121000.0     0.009235        Green      0.009170
# 11       2.149100        268950000.0    -0.091454          Red     -0.091340
# 12       2.240550        268950000.0     0.059076        Green      0.058920
# 18       2.500200        268637000.0    -0.043572          Red     -0.044160
# ...           ...                ...          ...          ...           ...
# 70314    0.482442        253799000.0     0.019626        Green      0.019737
# 70320    0.563641        253799000.0    -0.018599          Red     -0.018421
# 70321    0.582239        253799000.0     0.017970        Green      0.018000
# 70327    0.516505        253799000.0     0.007291        Green      0.007214
# 70328    0.509214        253799000.0    -0.011092          Red     -0.011099
#
#       mc_stats  clusters   weekday        BC
# 4          low         0    Sunday  7.449351
# 5          low         0  Saturday  7.389698
# 11         low         0    Sunday  7.464433
# 12         low         0  Saturday  7.425927
# 18         low         0    Sunday  7.472767
# ...        ...       ...       ...       ...
# 70314      low         0  Saturday  7.421737
# 70320      low         0    Sunday  7.381736
# 70321      low         0  Saturday  7.471187
# 70327      low         0    Sunday  7.216780
# 70328      low         0  Saturday  7.203030
#
# [20084 rows x 20 columns]

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(weekends['Price change'], bins = 1000, edgecolor = "black", align = 'mid')
ax.set_title('Weekends Price Change Plot')
ax.set_xlabel('Price Change')
ax.set_ylabel('Frequency')
plt.show()

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(weekends['Price change'], bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Weekends Price Change Plot')
ax.set_xlabel('Price Change')
ax.set_ylabel('Frequency')
ax.set_ylim(0,500)
plt.show()

# %% [markdown]
# In this plot, it seems our data is normal.
#
# We will use further tests to determine that.

# %% [markdown]
# Shapiro Normality test:

# %%
from scipy.stats import shapiro
stat, p = shapiro(weekends['Price change'])
p
# Out:
# c:\Users\ROG\anaconda3\envs\MLB\lib\site-packages\scipy\stats\_morestats.py:1882: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# 0.0

# %% [markdown]
# The Shapiro test rejects normlity!

# %% [markdown]
# D'Agostino Normality test:

# %%
from scipy.stats import normaltest
stat, p = normaltest(weekends['Price change'])
p
# Out:
# 0.0

# %% [markdown]
# The D'Agostino test rejects normlity too!

# %% [markdown]
# These test are valid for data around 5000 or less and in this case our data seems a very narrow normal distribution, therefore these tests won't be able to accept it's normality but our data isn't that far from being normal, being a Lepokurtic set!

# %% [markdown]
# Let's see some additional data interpretation!

# %% [markdown]
# Most used exchanges:

# %%
cu.execute('select * from coinexchange')
tab3=cu.fetchall()
coinexchange=pd.DataFrame(tab3,columns=['name', 'exchange'])
coinexchange
# Out:
#           name           exchange
# 0      Bitcoin            Binance
# 1      Bitcoin  Coinbase Exchange
# 2      Bitcoin            Binance
# 3      Bitcoin            Binance
# 4      Bitcoin             KuCoin
# ..         ...                ...
# 215  Chainlink  Coinbase Exchange
# 216  Chainlink             Kraken
# 217  Chainlink            Bithumb
# 218  Chainlink             Kraken
# 219  Chainlink            Binance
#
# [220 rows x 2 columns]

# %%
coinexchange = coinexchange.drop_duplicates()
coinexchange
# Out:
#           name           exchange
# 0      Bitcoin            Binance
# 1      Bitcoin  Coinbase Exchange
# 4      Bitcoin             KuCoin
# 5      Bitcoin             Kraken
# 9      Bitcoin           Bitstamp
# ..         ...                ...
# 210  Chainlink            Binance
# 211  Chainlink  Coinbase Exchange
# 214  Chainlink             KuCoin
# 216  Chainlink             Kraken
# 217  Chainlink            Bithumb
#
# [107 rows x 2 columns]

# %%
fig , ax = plt.subplots(figsize=(20,10))
plt.hist(coinexchange['exchange'],bins = 100, edgecolor = "black", align = 'mid')
ax.set_title('Exchanges Plot')
ax.set_xlabel('Exchanges')
ax.set_ylabel('Frequency')
plt.xticks(rotation=45, ha="right")  

plt.show()

# %% [markdown]
# Most used pairs in exchanges:

# %%
cu.execute('select * from exchangepair')
tab4=cu.fetchall()
pairex=pd.DataFrame(tab4,columns=['name', 'pair'])
pairex
# Out:
#                   name       pair
# 0              Binance   BTC/USDT
# 1    Coinbase Exchange    BTC/USD
# 2              Binance   BTC/TUSD
# 3              Binance  BTC/FDUSD
# 4               KuCoin   BTC/USDT
# ..                 ...        ...
# 215  Coinbase Exchange  LINK/USDT
# 216             Kraken   LINK/USD
# 217            Bithumb   LINK/KRW
# 218             Kraken   LINK/EUR
# 219            Binance   LINK/EUR
#
# [220 rows x 2 columns]

# %%
pairex = pairex.drop_duplicates()
pairex
# Out:
#                   name       pair
# 0              Binance   BTC/USDT
# 1    Coinbase Exchange    BTC/USD
# 2              Binance   BTC/TUSD
# 3              Binance  BTC/FDUSD
# 4               KuCoin   BTC/USDT
# ..                 ...        ...
# 215  Coinbase Exchange  LINK/USDT
# 216             Kraken   LINK/USD
# 217            Bithumb   LINK/KRW
# 218             Kraken   LINK/EUR
# 219            Binance   LINK/EUR
#
# [215 rows x 2 columns]

# %%
p = pairex.groupby('pair')['name'].count().sort_values(ascending = False).reset_index().head(5)
p
# Out:
#         pair  name
# 0   LEO/USDT     5
# 1   TON/USDT     5
# 2   SOL/USDT     3
# 3   BTC/USDT     3
# 4  LINK/USDT     3
# 5    LTC/EUR     3
# 6  USDC/USDT     3
# 7    XRP/USD     3
# 8    ADA/EUR     3
# 9   ETH/USDT     3

# %%
explode = (0.1, 0.0, 0.2, 0.3, 0.0,0.1, 0.0, 0.2, 0.3, 0.0)
colors = ( "orange", "cyan", "brown", 'green', 'yellow', 'white',
           'gray', "indigo", "beige", 'blue')
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts = ax.pie(p['name'],
                                  explode = explode,
                                  labels = p['name'].astype('str'),
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))

ax.legend(wedges, p['pair'],
          title ="Pairs",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))

ax.set_title('Pairs Plot')
plt.show()
